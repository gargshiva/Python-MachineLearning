# %%
#pandas - Dataframes : table format data structure. Similiar of DF in Apache Spark.

import pandas as pd

# %%
#Create Series from Lists
s1= pd.Series([1,2,3,4,5])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s2=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s2)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
d1={"Spark":10,"Flink":20,"MapReduce":30}
engines=pd.Series(d1)
print(engines)
# Out:
# Spark        10
# Flink        20
# MapReduce    30
# dtype: int64

# %%
#Dataframe from Dictionary. Keys become the column name

# %%
student={"Student_name":['Bob','John','Wick'],"Student_Marks":[10,20,30]}

# %%
stdDF=pd.DataFrame(student)
print(stdDF)
# Out:
#   Student_name  Student_Marks
# 0          Bob             10
# 1         John             20
# 2         Wick             30

# %%
#Dataframe from csv file

# %%
goi = pd.read_csv("/Users/shigarg1/Downloads/GOI.csv")

# %%
goi.head(1100)
# Out:
#            Category Country/ States/ Union Territories Name  \
# 0           Country                                   INDIA
# 1             State                          Andhra Pradesh
# 2             State                       Arunachal Pradesh
# 3             State                                   Assam
# 4             State                                   Bihar
# 5             State                            Chhattisgarh
# 6             State                                     Goa
# 7             State                                 Gujarat
# 8             State                                 Haryana
# 9             State                        Himachal Pradesh
# 10            State                         Jammu & Kashmir
# 11            State                               Jharkhand
# 12            State                               Karnataka
# 13            State                                  Kerala
# 14            State                          Madhya Pradesh
# ...

# %%
goi.tail(3)
# Out:
#            Category Country/ States/ Union Territories Name  \
# 33  Union Territory                             Lakshadweep
# 34  Union Territory                            NCT of Delhi
# 35  Union Territory                              Puducherry
#
#     Literacy Rate (Persons) - Total - 2001  \
# 33                                    86.7
# 34                                    81.7
# 35                                    81.2
#
#     Literacy Rate (Persons) - Total - 2011  \
# 33                                    91.8
# 34                                    86.2
# 35                                    85.8
#
#     Literacy Rate (Persons) - Rural - 2001  \
# 33                                    85.0
# 34                                    78.1
# 35                                    74.0
#
#     Literacy Rate (Persons) - Rural - 2011  \
# 33                                    91.6
# 34                                    81.9
# 35                                    80.1
#
# ...

# %%
goi.describe()
# Out:
#        Literacy Rate (Persons) - Total - 2001  \
# count                               36.000000
# mean                                69.433333
# std                                 10.647709
# min                                 47.000000
# 25%                                 62.975000
# 50%                                 68.700000
# 75%                                 77.225000
# max                                 90.900000
#
#        Literacy Rate (Persons) - Total - 2011  \
# count                               36.000000
# mean                                77.711111
# std                                  8.497723
# min                                 61.800000
# 25%                                 71.725000
# 50%                                 76.600000
# 75%                                 85.850000
# max                                 94.000000
#
#        Literacy Rate (Persons) - Rural - 2001  \
# count                               36.000000
# ...

# %%
goi.iloc[20:23,0:4]
# Out:
#    Category Country/ States/ Union Territories Name  \
# 20    State                                  Odisha
# 21    State                                  Punjab
# 22    State                               Rajasthan
#
#     Literacy Rate (Persons) - Total - 2001  \
# 20                                    63.1
# 21                                    69.7
# 22                                    60.4
#
#     Literacy Rate (Persons) - Total - 2011
# 20                                    72.9
# 21                                    75.8
# 22                                    66.1

# %%
goi.loc[20:23,("Country/ States/ Union Territories Name","Literacy Rate (Persons) - Total - 2001","Literacy Rate (Persons) - Total - 2011")]
# Out:
#    Country/ States/ Union Territories Name  \
# 20                                  Odisha
# 21                                  Punjab
# 22                               Rajasthan
# 23                                  Sikkim
#
#     Literacy Rate (Persons) - Total - 2001  \
# 20                                    63.1
# 21                                    69.7
# 22                                    60.4
# 23                                    68.8
#
#     Literacy Rate (Persons) - Total - 2011
# 20                                    72.9
# 21                                    75.8
# 22                                    66.1
# 23                                    81.4

# %%
#Operations on DataFrame

literateStates = goi[(goi['Literacy Rate (Persons) - Total - 2011'] > 50) & (goi['Category'] == "State")]

# %%
literateStates.head(10)
# Out:
#    Category Country/ States/ Union Territories Name  \
# 1     State                          Andhra Pradesh
# 2     State                       Arunachal Pradesh
# 3     State                                   Assam
# 4     State                                   Bihar
# 5     State                            Chhattisgarh
# 6     State                                     Goa
# 7     State                                 Gujarat
# 8     State                                 Haryana
# 9     State                        Himachal Pradesh
# 10    State                         Jammu & Kashmir
#
#     Literacy Rate (Persons) - Total - 2001  \
# 1                                     60.5
# 2                                     54.3
# 3                                     63.3
# 4                                     47.0
# 5                                     64.7
# 6                                     82.0
# 7                                     69.1
# ...
